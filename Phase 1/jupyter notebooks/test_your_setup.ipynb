# %% [markdown]
# # Test your data analysis setup

# %%
import pandas as pd

# %%
import numpy as np

# %%
series = pd.Series([1, 3, 4, 5, np.nan, 6, 9])

series # calling a variable will output below
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    5.0
# 4    NaN
# 5    6.0
# 6    9.0
# dtype: float64

# %% [markdown]
# # How did you arrive at your conclusion?
#     Using the data in the csv, it appears Brazil has won the most competitions so far. Therefore they have better chances of winning subseqent competitions.
# # What pieces of data informed your decision?
#     Specifically column 3
# # Could the data be interpreted in another way to answer the question differently?
#     Yes, perhaps we could look at the runners up and say the country who has been runner-up the most could have better chances of winning the next world cup as they have come pretty far in previous competitions.

# %% [markdown]
# # Which nation has won the most World Cups?
#     Brazil
# # Which nation has come runner-up the most times?
#     Germany
# # Which nations have never won a World Cup?
#     Netherlands, Czechoslovakia, Sweden, Hungary, USA, Austria, Chile, Portugal, Poland, Croatia, Turkey, Korea Republic, Bulgaria, England, Belgium, Soviet Union, Yugoslavia.
# # Therefore; which nation is the best and which nation is the worst at football?
#     Best: Brazil
#     Worst: Soviet Union

# %%
import pandas as pd

coffee_per_day = [1, 5, 8, 5, 4, 3, 2]
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

series_one = pd.Series(coffee_per_day, index=days)

series_one.tail()
# Out:
# Wednesday    8
# Thursday     5
# Friday       4
# Saturday     3
# Sunday       2
# dtype: int64

# %%
import pandas as pd

workout_dictionary = {
    "Monday" : "Core & Cardio",
    "Tuesday" : "Arms & Back", 
    "Wednesday" : "Rest Day", 
    "Thursday" : "Legs & Shoulders", 
    "Friday" : "Chest & Cardio", 
    "Saturday" : "Rest Day", 
    "Sunday" : "Calisthenics"
}

workout_series = pd.Series(workout_dictionary)

workout_series
# Out:
# Monday          Core & Cardio
# Tuesday           Arms & Back
# Wednesday            Rest Day
# Thursday     Legs & Shoulders
# Friday         Chest & Cardio
# Saturday             Rest Day
# Sunday           Calisthenics
# dtype: object

# %%
import pandas as pd

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

restful_life = pd.Series("Rest!", days)

restful_life
# Out:
# Monday       Rest!
# Tuesday      Rest!
# Wednesday    Rest!
# Thursday     Rest!
# Friday       Rest!
# Saturday     Rest!
# Sunday       Rest!
# dtype: object

# %%
import pandas as pd

# Over 18 holes of disc golf, Amira, Steve and I have been keeping our scores

dict_scorecard = {
"Will" : [5, 4, 3, 3, 4, 4, 2, 3, 4, 4, 7, 4, 3, 3, 4, 3, 2, 3],
"Amira" : [3, 4, 2, 3, 4, 4, 5, 3, 5, 2, 5, 2, 4, 5, 4, 3, 4, 3],
"Steve" : [3, 4, 3, 4, 5, 3, 2, 5, 2, 5, 3, 5, 4, 4, 3, 2, 5, 3]
}

# I want to load these scores into a DataFrame to see them better

score_frame = pd.DataFrame(dict_scorecard, index=[i for i in range(1,19)])

score_frame.head(17)
# Out:
#     Will  Amira  Steve
# 1      5      3      3
# 2      4      4      4
# 3      3      2      3
# 4      3      3      4
# 5      4      4      5
# 6      4      4      3
# 7      2      5      2
# 8      3      3      5
# 9      4      5      2
# 10     4      2      5
# 11     7      5      3
# 12     4      2      5
# 13     3      4      4
# 14     3      5      4
# 15     4      4      3
# 16     3      3      2
# 17     2      4      5

# %%
import pandas as pd

# workout chart
workout_dictionary = {
    "Monday" : "Core & Cardio",
    "Tuesday" : "Arms & Back", 
    "Wednesday" : "Rest Day", 
    "Thursday" : "Legs & Shoulders", 
    "Friday" : "Chest & Cardio", 
    "Saturday" : "Rest Day", 
    "Sunday" : "Calisthenics"
}

workout_series = pd.Series(workout_dictionary)

# coffee chart
coffee_per_day = [1, 5, 8, 5, 4, 3, 2]
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

series_one = pd.Series(coffee_per_day, index=days)

# putting them together
coffees_vs_workout = {
    "coffee" : series_one,
    "workout" : workout_series 
}

pd.DataFrame(coffees_vs_workout)
# Out:
#            coffee           workout
# Monday          1     Core & Cardio
# Tuesday         5       Arms & Back
# Wednesday       8          Rest Day
# Thursday        5  Legs & Shoulders
# Friday          4    Chest & Cardio
# Saturday        3          Rest Day
# Sunday          2      Calisthenics

# %%
file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

winners_frame.shape
# Out:
# (20, 10)

# %%
file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

winners_frame["GoalsScored"]
# Out:
# 0      70
# 1      70
# 2      84
# 3      88
# 4     140
# 5     126
# 6      89
# 7      89
# 8      95
# 9      97
# 10    102
# 11    146
# 12    132
# 13    115
# 14    141
# 15    171
# 16    161
# 17    147
# 18    145
# 19    171
# Name: GoalsScored, dtype: int64

# %%
file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

winners_frame["GoalsScored"].mean()
# Out:
# 118.95

# %%
file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

three_cols = winners_frame.columns[0:3]
winners_frame[three_cols]
# Out:
#     Year       Country      Winner
# 0   1930       Uruguay     Uruguay
# 1   1934         Italy       Italy
# 2   1938        France       Italy
# 3   1950        Brazil     Uruguay
# 4   1954   Switzerland  Germany FR
# 5   1958        Sweden      Brazil
# 6   1962         Chile      Brazil
# 7   1966       England     England
# 8   1970        Mexico      Brazil
# 9   1974       Germany  Germany FR
# 10  1978     Argentina   Argentina
# 11  1982         Spain       Italy
# 12  1986        Mexico   Argentina
# 13  1990         Italy  Germany FR
# 14  1994           USA      Brazil
# 15  1998        France      France
# 16  2002   Korea/Japan      Brazil
# 17  2006       Germany       Italy
# 18  2010  South Africa       Spain
# 19  2014        Brazil     Germany

# %%
import matplotlib.pyplot as plt

file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

group = winners_frame.groupby('Year')[['GoalsScored']].sum()

group.plot(kind='barh', figsize=(20, 15))
plt.title('Goals Scored by Year', fontdict={'fontsize': 30, 'weight': 'bold'}, pad=30)
plt.show()

# %%
import matplotlib.pyplot as plt

file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/world_cup/WorldCups.csv")

winners_frame = pd.DataFrame(file)

group = winners_frame.groupby('Country')[['MatchesPlayed']].sum()

group.plot(kind='barh', figsize=(20, 15))
plt.title('Matches Played by Country', fontdict={'fontsize': 30, 'weight': 'bold'}, pad=30)
plt.show()

# %%
import pandas as pd

# Over 18 holes of disc golf in March, Amira, Steve and I have been keeping our scores

march_dict_scorecard = {
"Will" : [8, 4, 3, 3, 4, 4, 2, 3, 4, 4, 7, 4, 3, 3, 4, 3, 2, 3],
"Amira" : [3, 2, 2, 3, 4, 7, 5, 3, 5, 2, 5, 2, 4, 5, 4, 3, 4, 3],
"Steve" : [2, 4, 2, 4, 5, 3, 2, 5, 2, 5, 3, 5, 4, 4, 3, 2, 6, 3]
}

# I want to load these scores into a DataFrame to see them better

march_score_frame = pd.DataFrame(march_dict_scorecard, index=range(1, 19))

print(march_score_frame)


# Over 18 holes of disc golf in April, Amira, Steve and I have been keeping our scores

april_dict_scorecard = {
"Will" : [3, 4, 2, 3, 4, 4, 2, 2, 3, 4, 4, 6, 3, 2, 4, 3, 3, 3],
"Amira" : [3, 4, 2, 3, 4, 3, 5, 3, 5, 2, 4, 2, 4, 5, 4, 3, 4, 3],
"Steve" : [3, 2, 3, 4, 5, 3, 2, 5, 2, 5, 2, 6, 4, 4, 3, 2, 4, 3]
}

# I want to load these scores into a DataFrame to see them better

hole_index = pd.Index(range(1, 19), name='Course Hole')

april_score_frame = pd.DataFrame(april_dict_scorecard, index=hole_index)
march_score_frame = pd.DataFrame(march_dict_scorecard, index=hole_index)

march_score_frame.join(april_score_frame, lsuffix=" (March)", rsuffix=" (April)")
# Out:
#     Will  Amira  Steve
# 1      8      3      2
# 2      4      2      4
# 3      3      2      2
# 4      3      3      4
# 5      4      4      5
# 6      4      7      3
# 7      2      5      2
# 8      3      3      5
# 9      4      5      2
# 10     4      2      5
# 11     7      5      3
# 12     4      2      5
# 13     3      4      4
# 14     3      5      4
# 15     4      4      3
# 16     3      3      2
# 17     2      4      6
# 18     3      3      3
#              Will (March)  Amira (March)  Steve (March)  Will (April)  \
# Course Hole
# 1                       8              3              2             3
# 2                       4              2              4             4
# 3                       3              2              2             2
# 4                       3              3              4             3
# 5                       4              4              5             4
# 6                       4              7              3             4
# ...

# %%
import pandas as pd

hap15 = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/happiness_data/2015.csv")

print(hap15.head())

print(hap15.info())
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
hap16 = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/happiness_data/2016.csv")

print(hap16.head())

print(hap16.info())
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
joined_table = hap15.join(hap16, how="outer", lsuffix="_2015", rsuffix="_2016")

print(f"The leading 5 happiness countries in 2015 were \n {joined_table['Country_2015'].head()}. \n Whereas in 2016 they were \n {joined_table['Country_2016'].head()}.")
# Out:
# The leading 5 happiness countries in 2015 were
#  0    Switzerland
# 1        Iceland
# 2        Denmark
# 3         Norway
# 4         Canada
# Name: Country_2015, dtype: object.
#  Whereas in 2016 they were
#  0        Denmark
# 1    Switzerland
# 2        Iceland
# 3         Norway
# 4        Finland
# Name: Country_2016, dtype: object.

# %%
hap_merged = pd.merge(hap16, hap15, on="Country", suffixes=[" 2016", " 2015"])

hap_merged.head()
# Out:
#        Country     Region 2016  Happiness Rank 2016  Happiness Score 2016  \
# 0      Denmark  Western Europe                    1                 7.526
# 1  Switzerland  Western Europe                    2                 7.509
# 2      Iceland  Western Europe                    3                 7.501
# 3       Norway  Western Europe                    4                 7.498
# 4      Finland  Western Europe                    5                 7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita) 2016  Family 2016  Health (Life Expectancy) 2016  \
# 0                        1.44178      1.16374                        0.79504
# ...

# %%
hap_merged = pd.merge(hap16, hap15, on=["Country", "Region"], suffixes=[" 2016", " 2015"])

hap_merged.head()
# Out:
#        Country          Region  Happiness Rank 2016  Happiness Score 2016  \
# 0      Denmark  Western Europe                    1                 7.526
# 1  Switzerland  Western Europe                    2                 7.509
# 2      Iceland  Western Europe                    3                 7.501
# 3       Norway  Western Europe                    4                 7.498
# 4      Finland  Western Europe                    5                 7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita) 2016  Family 2016  Health (Life Expectancy) 2016  \
# 0                        1.44178      1.16374                        0.79504
# ...

# %%
import pandas as pd

hap18 = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/happiness_data/2018.csv")
hap19 = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/happiness_data/2019.csv")


hap18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
hap19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
hap18_and_19_merged = hap18.join(hap19, how="inner", lsuffix="_2018", rsuffix="_2019")

hap18_and_19_merged.head()
# Out:
#    Overall rank_2018 Country or region_2018  Score_2018  GDP per capita_2018  \
# 0                  1                Finland       7.632                1.305
# 1                  2                 Norway       7.594                1.456
# 2                  3                Denmark       7.555                1.351
# 3                  4                Iceland       7.495                1.343
# 4                  5            Switzerland       7.487                1.420
#
#    Social support_2018  Healthy life expectancy_2018  \
# 0                1.592                         0.874
# 1                1.582                         0.861
# 2                1.590                         0.868
# 3                1.644                         0.914
# 4                1.549                         0.927
#
#    Freedom to make life choices_2018  Generosity_2018  \
# 0                              0.681            0.202
# 1                              0.686            0.286
# ...

# %%
rank_country_score_merge = hap18[['Overall rank','Country or region', 'Score']].join(hap19[['Overall rank','Country or region', 'Score']], how="inner", lsuffix="_2018", rsuffix="_2019")

rank_country_score_merge.head()
# Out:
#    Overall rank_2018 Country or region_2018  Score_2018  Overall rank_2019  \
# 0                  1                Finland       7.632                  1
# 1                  2                 Norway       7.594                  2
# 2                  3                Denmark       7.555                  3
# 3                  4                Iceland       7.495                  4
# 4                  5            Switzerland       7.487                  5
#
#   Country or region_2019  Score_2019
# 0                Finland       7.769
# 1                Denmark       7.600
# 2                 Norway       7.554
# 3                Iceland       7.494
# 4            Netherlands       7.488

# %%
hap_merged = pd.merge(hap18[['Overall rank','Country or region', 'Score']], hap19[['Overall rank','Country or region', 'Score']], on="Country or region", suffixes=[" 2018", " 2019"])
hap_merged
# Out:
#      Overall rank 2018         Country or region  Score 2018  \
# 0                    1                   Finland       7.632
# 1                    2                    Norway       7.594
# 2                    3                   Denmark       7.555
# 3                    4                   Iceland       7.495
# 4                    5               Switzerland       7.487
# ..                 ...                       ...         ...
# 147                152                     Yemen       3.355
# 148                153                  Tanzania       3.303
# 149                154               South Sudan       3.254
# 150                155  Central African Republic       3.083
# 151                156                   Burundi       2.905
#
#      Overall rank 2019  Score 2019
# 0                    1       7.769
# 1                    3       7.554
# 2                    2       7.600
# 3                    4       7.494
# 4                    6       7.480
# ...

# %%
file = pd.read_csv("~/Projects/intro-to-data-analysis/data/extra-challenge/cereals/cereal.csv")

cereals = pd.DataFrame(file)

# %%
my_cereal = {
    'name': ['Ilhaamies'],
    'mfr': ['K'],
    'type': ['C'],
    'calories': [85],
    'protein': [5],
    'fat': [2],
    'sodium': [200],
    'fiber': [3],
    'carbo': [20],
    'sugars': [8],
    'potass': [150],
    'vitamins': [10],
    'shelf': [3],
    'weight': [1],
    'cups': [0.75],
    'rating': [68.45367]
}

my_cereal_data = pd.DataFrame(my_cereal)

# %%
combine_to_df = pd.merge(cereals, my_cereal_data, on=['name'], suffixes=('_original', '_new_type'))

# %%
ilhaam_cereal = {
    'name': ['wheatils'],
    'mfr': ['G'],
    'type': ['C'],
    'calories': [70],
    'protein': [3],
    'fat': [0],
    'sodium': [220],
    'fiber': [6],
    'carbo': [15],
    'sugars': [7],
    'potass': [100],
    'vitamins': [20],
    'shelf': [2],
    'weight': [1],
    'cups': [0.6],
    'rating': [62.67839]
}

ilhaams_cereal_data = pd.DataFrame(ilhaam_cereal)
ilhaams_cereal_data
# Out:
#        name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0  wheatils   G    C        70        3    0     220      6     15       7
#
#    potass  vitamins  shelf  weight  cups    rating
# 0     100        20      2       1   0.6  62.67839

# %%
ilfrost_cereal = {
    'name': ['ilfrost'],
    'mfr': ['K'],
    'type': ['C'],
    'calories': [100],
    'protein': [1],
    'fat': [1],
    'sodium': [200],
    'fiber': [1],
    'carbo': [15],
    'sugars': [11],
    'potass': [25],
    'vitamins': [20],
    'shelf': [1],
    'weight': [1],
    'cups': [0.75],
    'rating': [40.35648]
}

ilfrost_cereal_data = pd.DataFrame(ilfrost_cereal)
ilfrost_cereal_data
# Out:
#       name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0  ilfrost   K    C       100        1    1     200      1     15      11
#
#    potass  vitamins  shelf  weight  cups    rating
# 0      25        20      1       1  0.75  40.35648

# %%
more_brands_joined = pd.concat([cereals, ilhaams_cereal_data, ilfrost_cereal_data], ignore_index=True)
more_brands_joined
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C      70.0        4    1     130   10.0
# 1           100% Natural Bran   Q    C     120.0        3    5      15    2.0
# 2                    All-Bran   K    C      70.0        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C      50.0        4    0     140   14.0
# 4              Almond Delight   R    C     110.0        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 74                 Wheat Chex   R    C     100.0        3    1     230    3.0
# 75                   Wheaties   G    C     100.0        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C     110.0        2    1     200    1.0
# 77                   wheatils   G    C      70.0        3    0     220    6.0
# 78                    ilfrost   K    C     100.0        1    1     200    1.0
#
# ...

# %%
reduced_sugar_df = cereals.copy()
reduced_sugar_df['sugars'] = reduced_sugar_df['sugars'] * 0.8

# %%
compare_df = pd.merge(cereals, reduced_sugar_df, on=['name', 'mfr'], suffixes=('_original', '_reduced_sugars'))

# %%
all_cereal = pd.DataFrame(compare_df)
all_cereal
# Out:
#                          name mfr type_original  calories_original  \
# 0                   100% Bran   N             C               70.0
# 1           100% Natural Bran   Q             C              120.0
# 2                    All-Bran   K             C               70.0
# 3   All-Bran with Extra Fiber   K             C               50.0
# 4              Almond Delight   R             C              110.0
# ..                        ...  ..           ...                ...
# 72                    Triples   G             C              110.0
# 73                       Trix   G             C              110.0
# 74                 Wheat Chex   R             C              100.0
# 75                   Wheaties   G             C              100.0
# 76        Wheaties Honey Gold   G             C              110.0
#
#     protein_original  fat_original  sodium_original  fiber_original  \
# 0                  4             1              130            10.0
# ...

# %%
count = len(all_cereal[all_cereal['protein_original'] > 3])
print(f"The number of cereals with protein content above 3 are: {count}")
# Out:
# The number of cereals with protein content above 3 are: 11

# %%
k_cereals = all_cereal[all_cereal['mfr'] == 'K']
k_cereals
# Out:
#                            name mfr type_original  calories_original  \
# 2                      All-Bran   K             C               70.0
# 3     All-Bran with Extra Fiber   K             C               50.0
# 6                   Apple Jacks   K             C              110.0
# 16                  Corn Flakes   K             C                NaN
# 17                    Corn Pops   K             C              110.0
# 19           Cracklin' Oat Bran   K             C              110.0
# 21                      Crispix   K             C              110.0
# 24                  Froot Loops   K             C              110.0
# 25               Frosted Flakes   K             C              110.0
# 26          Frosted Mini-Wheats   K             C              100.0
# 28                Fruitful Bran   K             C              120.0
# 38  Just Right Crunchy  Nuggets   K             C              110.0
# 39       Just Right Fruit & Nut   K             C              140.0
# ...
